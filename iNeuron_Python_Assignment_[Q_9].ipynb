# %% [markdown]
# # Question 9:
#
# Write a program to read the data from the following link, perform data analysis and answer the following
# questions
# Note -
# 1. Write code comments wherever required for code understanding
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
#
# Insights to be drawn -
# - Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# - Get all TESLA cars with the model year, and model type made in Bothell City.
# - Get all the cars that have an electric range of more than 100, and were made after 2015
# - Draw plots to show the distribution between city and electric vehicle type

# %%
import pandas as pd 

# Importing CSV using read csv

df = pd.read_csv('https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD')
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
# Get all the cars and their types that do not qualify for clean alternative fuel vehicle

df[['Make','Model','Electric Vehicle Type']][df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] != 'Clean Alternative Fuel Vehicle Eligible '].groupby(['Model','Make','Electric Vehicle Type']).size().reset_index()
# Out:
#     Model   Make                   Electric Vehicle Type     0
# 0    330E    BMW  Plug-in Hybrid Electric Vehicle (PHEV)   397
# 1     500   FIAT          Battery Electric Vehicle (BEV)   803
# 2    530E    BMW  Plug-in Hybrid Electric Vehicle (PHEV)   376
# 3    740E    BMW  Plug-in Hybrid Electric Vehicle (PHEV)    26
# 4    745E    BMW  Plug-in Hybrid Electric Vehicle (PHEV)     9
# ..    ...    ...                                     ...   ...
# 119    X3    BMW  Plug-in Hybrid Electric Vehicle (PHEV)   286
# 120    X5    BMW  Plug-in Hybrid Electric Vehicle (PHEV)  1887
# 121  XC40  VOLVO          Battery Electric Vehicle (BEV)   495
# 122  XC60  VOLVO  Plug-in Hybrid Electric Vehicle (PHEV)   858
# 123  XC90  VOLVO  Plug-in Hybrid Electric Vehicle (PHEV)  1139
#
# [124 rows x 4 columns]

# %%
# Get all TESLA cars with the model year, and model type made in Bothell City.

df[['Model','Model Year','Electric Vehicle Type']][(df['Make'] == 'TESLA') & (df['City'] == 'Bothell')]
# Out:
#           Model  Model Year           Electric Vehicle Type
# 39      MODEL 3        2020  Battery Electric Vehicle (BEV)
# 217     MODEL 3        2022  Battery Electric Vehicle (BEV)
# 218     MODEL Y        2022  Battery Electric Vehicle (BEV)
# 222     MODEL 3        2018  Battery Electric Vehicle (BEV)
# 292     MODEL X        2017  Battery Electric Vehicle (BEV)
# ...         ...         ...                             ...
# 129778  MODEL 3        2019  Battery Electric Vehicle (BEV)
# 129954  MODEL 3        2021  Battery Electric Vehicle (BEV)
# 129976  MODEL S        2014  Battery Electric Vehicle (BEV)
# 130295  MODEL 3        2022  Battery Electric Vehicle (BEV)
# 130392  MODEL 3        2018  Battery Electric Vehicle (BEV)
#
# [2407 rows x 3 columns]

# %%
# Get all the cars that have an electric range of more than 100, and were made after 2015


df[(df['Electric Range'] >100 ) & (df['Model Year'] > 2015)]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %%
# Draw plots to show the distribution between city and electric vehicle type

import seaborn as sns

sns.countplot(x= 'Electric Vehicle Type',data = df)
# Out:
# <Axes: xlabel='Electric Vehicle Type', ylabel='count'>

# %%
# As there are so many cities we cannot plot cities 
sns.countplot(x= 'City',data = df)
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
df['City'].nunique()
# Out:
# 656
